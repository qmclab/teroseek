# %%
import pandas as pd


df_all = pd.read_csv(".data/available_TA_all.csv")
df_all = df_all[df_all["relevant"]==2]
df_topic = pd.read_csv("df_introduction.csv")
df_all.head()
# Out:
#        T_id                        doi  \
# 0  TA000000      10.3390/foods10061207
# 1  TA000001  10.3390/molecules23112838
# 2  TA000002  10.3390/molecules27113580
# 3  TA000003  10.3390/molecules23112803
# 4  TA000004  10.1007/s10532-013-9619-4
#
#                                                title  \
# 0  Yeast Particle Encapsulation of Scaffolded Ter...
# 1  Volatile Terpenes and Terpenoids from Workers ...
# 2  Yeast Particles Hyper-Loaded with Terpenes for...
# 3  Olfactory Impact of Terpene Alcohol on Terpene...
# 4  Using volatile organic compounds to enhance at...
#
#                                             abstract  \
# 0  Terpenes are naturally occurring compounds pro...
# 1  Twenty-one volatile terpenes and terpenoids we...
# 2  Yeast particles (YPs) are 3−5 µm hollow and po...
# 3  The key point of our work was evaluating the i...
# 4  The effect of the terpenes alpha-pinene, eucal...
#
#                                              authors  year  \
# 0  Soto, Ernesto R, Rus, Florentina, Li, Hanchen,...  2021
# 1  Zhao, Rui, Lu, Lihua, Shi, Qingxing, Chen, Jia...  2018
# 2  Soto, Ernesto R, Rus, Florentina, Ostroff, Gary R  2022
# 3  Niu, Yunwei, Sun, Xiaoxin, Xiao, Zuobing, Wang...  2018
# 4  Tortella, G. R.; Rubilar, O.; Stenstrom, J.; C...  2013
#
#                         publisher  relevant   wos  scopus  pubmed  \
# 0      Foods (Basel, Switzerland)         2  True    True    True
# 1  Molecules (Basel, Switzerland)         2  True    True    True
# 2  Molecules (Basel, Switzerland)         2  True    True    True
# 3  Molecules (Basel, Switzerland)         2  True    True    True
# 4                  Biodegradation         2  True    True   False
#
#                                         introduction  \
# 0  ["**1. introduction** Terpenes are a large cla...
# 1  ['**1. introduction** Terpenes and terpenoids ...
# 2  ["**1. introduction** Terpenes are a large cla...
# 3  ['**1. introduction** Chrysanthemums are of th...
# 4  ['introduction A factor influencing the succes...
#
#                                              methods  \
# 0  ['**2. materials and methods** ', '*2.1. mater...
# 1  ['**4. materials and methods** ', '*4.1. ants*...
# 2  ['mixture (1.65 g get at a composition of 2:1:...
# 3  ['**2. materials and methods** ', '*2.1. chemi...
# 4  ['materials and methods ', 'chemicals Analytic...
#
#                                              results  \
# 0  To investigate the toxicity of M. alternifolia...
# 1  To investigate the toxicity of M. alternifolia...
# 2  To investigate the toxicity of M. alternifolia...
# 3  To investigate the toxicity of M. alternifolia...
# 4  To investigate the toxicity of M. alternifolia...
#
#                                          discuession  \
# 0  ['**4. discussion** Terpenes are natural produ...
# 1  ["**3. discussion** Twenty-one terpenes and te...
# 2                 ['**2. results and discussion** ']
# 3  ['**3. results and discussion** used in plsr m...
# 4                                                NaN
#
#                                          conclustion
# 0  ['**5. conclusions** Yeast particles can be us...
# 1  ["**5. conclusions** In summary, twenty-one vo...
# 2  ['**4. conclusions** Yeast particles can be us...
# 3  ['**4. conclusions** The addition of isoborneo...
# 4  ['<span id="page-8-0"></span>conclusion Adding...

# %%
len(df_all[~df_all["conclustion"].isna()])
# Out:
# 20276

# %%
df_conclustion = df_all[~df_all["conclustion"].isna()]

# %%
rows = df_conclustion.sample(2)
rows
# Out:
#            T_id                              doi  \
# 21113  TA037217               10.3390/md10092069
# 11224  TA019976  10.1016/j.phytochem.2018.07.011
#
#                                                    title  \
# 21113  Isolation and characterization of a lycopene ε...
# 11224  Metabolic discrimination of pine resins using ...
#
#                                                 abstract  \
# 21113  The isolation and characterization of the lyco...
# 11224  Resins are one of the first sites of interacti...
#
#                                                  authors  year  \
# 21113  Cordero, Baldo F, Couso, Inmaculada, Leon, Ros...  2012
# 11224  Salome-Abarca, Luis Francisco; van der Pas, Jo...  2018
#
#             publisher  relevant    wos  scopus  pubmed  \
# 21113    Marine drugs         2  False   False    True
# 11224  PHYTOCHEMISTRY         2   True   False   False
#
#                                             introduction  \
# 21113  Carotenoids are essential pigments for all pho...
# 11224  ['1. introduction Plant resins have been used ...
#
#                                                  methods  \
# 21113  The green microalga strain Chlorella zofingien...
# 11224  ["4.1. sample collection Pine resins were coll...
#
#                                                  results  \
# 21113  Different pairs of degenerate primers were des...
# 11224  To investigate the toxicity of M. alternifolia...
#
#                                              discuession  \
# 21113  The carotenoid biosynthetic pathway is divided...
# 11224  ['2. results and discussion To investigate the...
#
#                                              conclustion
# 21113  Our results on the characterization of the Czl...
# 11224  ['3. conclusions The effect of the species and...

# %%
prompt = """
The topic is {}
=================
Discuession:{}
Based on the above information:
 - First, Divide the text reasonably, each paragraph should include the brief summary and the original text. 
 - Do not omit any information in original text, but you can clean it.
 - It is recommended to merge related paragraphs. Each output paragraph should be no less than 500 words.
 - No output in any format other than JSON is required. Translate it into English as a prompt.
EXAMPLE JSON OUTPUT:
{{
    "0001": {{
        "summary":"",
        "original_text":""，
    }},
    "0002": {{
        "summary":"",
        "original_text":"",
    }},
}}
The response is:
"""
llm_data = []
for _, row in df_conclustion.iterrows():
    T_id = row["T_id"]
    topic = df_topic[df_topic["T_id"]==T_id]["topic"].values[0]
    content = row["conclustion"]  ### 重要，记得修改
    llm_input = prompt.format(topic, content)
    llm_data.append({
        "custom_id": T_id,
        "llm_input": llm_input
    })
len(llm_data)
# Out:
# 20276

# %%
llm_data[10065]["llm_input"]
# Out:
# '\nThe topic is Isolation and cytotoxic evaluation of limonoids from the fruits of Khaya ivorensis.\n=================\nDiscuession:In summary, three mexicanolide-type limonoids, 14,15-didehydroruageanin A (1), 3-O-methylbutyrylseneganolide A (2), and seneganolide A (3), along with five known d-seco limonoids, 1,3-dideacetylkhivorin (4), 7-deacetylkhivorin (5), 3-deacetylkhivorin (6), 1-deacetylkhivorin (7) and 3-deacetyl-7-oxokhivorin (8), were isolated from the fruits of Khaya ivorensis. Among these compounds, 1 and 2 were new compounds; and compounds 3, 4, 7, and 8 were obtained from this plant for the first time. The cytotoxicity evaluation showed that only compounds 2, 3, and 4 exhibited cytotoxicity against certain tumor cell lines.\nBased on the above information:\n - First, Divide the text reasonably, each paragraph should include the brief summary and the original text. \n - Do not omit any information in original text, but you can clean it.\n - It is recommended to merge related paragraphs. Each output paragraph should be no less than 500 words.\n - No output in any format other than JSON is required. Translate it into English as a prompt.\nEXAMPLE JSON OUTPUT:\n{\n    "0001": {\n        "summary":"",\n        "original_text":""，\n    },\n    "0002": {\n        "summary":"",\n        "original_text":"",\n    },\n}\nThe response is:\n'

# %%
def data_to_jsonl_volcengine(datas:list, save_file_path=".tmp.jsonl"):
    import json
    # 火山引擎要求的jsonl格式
    with open(save_file_path, "w", encoding="utf-8") as f:
        for _data in datas:
            custom_id = _data["custom_id"]
            user_input = _data["llm_input"]
            _input = {
                "custom_id": custom_id,
                "body": {
                    "messages": [
                        {"role": "system","content": ""},
                        {"role": "user","content": user_input}
                    ],
                    "max_tokens": 10000,
                    "temperature": 0
                },
            }
            f.write(json.dumps(_input, ensure_ascii=False) + "\n")
    return

data_to_jsonl_volcengine(llm_data, "h_conclusion_input.jsonl")

# %%
import json
from tqdm import tqdm

conclusion_datas = []
err_ids = []

with open("h_conclusion_output.jsonl", "r") as r:
    for line in tqdm(r.readlines()):
        llm_data = json.loads(line)
        T_id = llm_data["custom_id"]
        llm_msg = llm_data["response"]["body"]["choices"][0]["message"]["content"]
        llm_msg = llm_msg.replace("`","").replace("json","").replace("\n","")
        try:
            msg_data = eval(llm_msg)
            _data = {"T_id": T_id}
            for k, v in msg_data.items():
                _data[k] = v
            conclusion_datas.append(_data)
        except:
            err_ids.append(T_id)

len(err_ids)
# Out:
# 100%|██████████| 20276/20276 [00:00<00:00, 22665.71it/s]
# 15

# %%
import pandas as pd

conclusion_df = pd.DataFrame(conclusion_datas)

conclusion_split_data = []
for _, row in tqdm(conclusion_df[:].iterrows()):
    T_id = row["T_id"]
    for column_name, value in row.items():  # 直接遍历Series的键值对
        if column_name == "T_id":
            continue
        if pd.isna(row[column_name]):
            break
        else:
            _data = {}
            _data["conclusion_id"] = T_id + "_C_" + column_name
            _data["summary"] = value["summary"]
            _data["original_text"] = value["original_text"] if "original_text" in value else None
            conclusion_split_data.append(_data)

# method_df
conclusion_split_df = pd.DataFrame(conclusion_split_data)
conclusion_split_df
# Out:
# 20261it [00:00, 35071.19it/s]
#          conclusion_id                                            summary  \
# 0      TA008817_C_0001  The study successfully generated and validated...
# 1      TA008386_C_0001  The discussion section acknowledges the contri...
# 2      TA008964_C_0001  The study demonstrates the cardioprotective ef...
# 3      TA008036_C_0001  The discussion section acknowledges the financ...
# 4      TA008993_C_0001  The study presents the first comprehensive ide...
# ...                ...                                                ...
# 27545  TA050693_C_0001  The document discusses the evaluation of 23 al...
# 27546  TA050693_C_0002  The document further details the need for spec...
# 27547  TA050865_C_0001  Introduction and definition of glycerol esters...
# 27548  TA050865_C_0002  Toxicological assessment of GEWR, including AD...
# 27549  TA050865_C_0003  Regulatory conclusions and recommendations for...
#
#                                            original_text
# 0      To conclude, we reported the successful genera...
# 1      acknowledgments The authors appreciate the hel...
# 2      This study's findings, validated through antio...
# 3      acknowledgements This work was financially sup...
# 4      In conclusion, this is the first comprehensive...
# ...                                                  ...
# 27545  The current revision of FGE.73Rev4 considers i...
# 27546  In order to determine whether the conclusion f...
# 27547  The present opinion deals with the re‐evaluati...
# 27548  The Panel noted that the current evaluation is...
# 27549  In 1994, the Scientific Committee on Food (SCF...
#
# [27550 rows x 3 columns]

# %%
conclusion_split_df.to_csv(".data/chunks_conclusion.csv", index=False)
