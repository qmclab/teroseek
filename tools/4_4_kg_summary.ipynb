# %%
import pandas as pd


df_all = pd.concat([
    pd.read_csv(".data/TA_KG_subject_nodes.csv"),
    pd.read_csv(".data/TA_KG_source_nodes.csv"),
    pd.read_csv(".data/TA_KG_method_nodes.csv"),
    pd.read_csv(".data/TA_KG_compounds_nodes.csv")
], ignore_index=True)

len(df_all)
# Out:
# 546040

# %%
def get_graph_data(T_id, rows):
    # rows.columns = ["T_id", "type", "data"]
    nodes_data_template = {
        "id": "0",
        "name": T_id,
        "symbolSize": 100,
        "x": 0,
        "y": 0,
        "value": 0,
        "category": 0
    }
    nodes = []  # {"source":"1", "target":"2"}
    links = []
    categories_data = {
        "T_id": 0,
        "subject": 1,
        "method": 2,
        "compound": 3,
        "source": 4
    }
    nodes.append(nodes_data_template)
    for idx, (_, row) in enumerate(rows.iterrows(), start=1):
        _nodes_data = nodes_data_template.copy()
        _nodes_data["id"] = str(idx)
        _nodes_data["symbolSize"] = 40
        _nodes_data["name"] = row["target"]
        _nodes_data["category"] = categories_data[row["type"]]
        _nodes_data["value"] = row["target"]
        nodes.append(_nodes_data)
        links.append({
            "source": "0",
            "target": str(idx)
        })
    return {
        "nodes": nodes,
        "links": links,
        "categories": [{"name": a} for a in categories_data.keys()]
    }

def parse_rows(rows):
    rows.loc[rows["subject"].notna(), "target"] = rows["subject"]
    rows.loc[rows["species"].notna(), "target"] = rows["species"]
    rows.loc[rows["method"].notna(), "target"] = rows["method"]
    rows.loc[rows["compound"].notna(), "target"] = rows["compound"]
    return rows

T_id = "TA000000"
rows = parse_rows(df_all[df_all["T_id"]==T_id])
get_graph_data("TA000000",rows)
# rows
# Out:
# {'nodes': [{'id': '0',
#    'name': 'TA000000',
#    'symbolSize': 100,
#    'x': 0,
#    'y': 0,
#    'value': 0,
#    'category': 0},
#   {'id': '1',
#    'name': 'Biotechnology',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Biotechnology',
#    'category': 1},
#   {'id': '2',
#    'name': 'Pharmaceutical Sciences',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Pharmaceutical Sciences',
#    'category': 1},
#   {'id': '3',
#    'name': 'Agricultural Sciences',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Agricultural Sciences',
#    'category': 1},
#   {'id': '4',
#    'name': 'Chemistry',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Chemistry',
#    'category': 1},
#   {'id': '5',
#    'name': 'Microbiology',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Microbiology',
#    'category': 1},
#   {'id': '6',
#    'name': 'Origanum vulgare',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Origanum vulgare',
#    'category': 4},
#   {'id': '7',
#    'name': 'Syzygium aromaticum',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Syzygium aromaticum',
#    'category': 4},
#   {'id': '8',
#    'name': 'Thymus vulgaris',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Thymus vulgaris',
#    'category': 4},
#   {'id': '9',
#    'name': 'Pelargonium graveolens',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'Pelargonium graveolens',
#    'category': 4},
#   {'id': '10',
#    'name': 'database search',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'database search',
#    'category': 2},
#   {'id': '11',
#    'name': 'target prediction',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'target prediction',
#    'category': 2},
#   {'id': '12',
#    'name': 'network construction',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'network construction',
#    'category': 2},
#   {'id': '13',
#    'name': 'enrichment analysis',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'enrichment analysis',
#    'category': 2},
#   {'id': '14',
#    'name': 'molecular docking',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'molecular docking',
#    'category': 2},
#   {'id': '15',
#    'name': 'molecular dynamics simulation',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'molecular dynamics simulation',
#    'category': 2},
#   {'id': '16',
#    'name': 'carvacrol',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'carvacrol',
#    'category': 3},
#   {'id': '17',
#    'name': 'eugenol',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'eugenol',
#    'category': 3},
#   {'id': '18',
#    'name': 'thymol',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'thymol',
#    'category': 3},
#   {'id': '19',
#    'name': 'geraniol',
#    'symbolSize': 40,
#    'x': 0,
#    'y': 0,
#    'value': 'geraniol',
#    'category': 3}],
#  'links': [{'source': '0', 'target': '1'},
#   {'source': '0', 'target': '2'},
#   {'source': '0', 'target': '3'},
#   {'source': '0', 'target': '4'},
#   {'source': '0', 'target': '5'},
#   {'source': '0', 'target': '6'},
#   {'source': '0', 'target': '7'},
#   {'source': '0', 'target': '8'},
#   {'source': '0', 'target': '9'},
#   {'source': '0', 'target': '10'},
#   {'source': '0', 'target': '11'},
#   {'source': '0', 'target': '12'},
#   {'source': '0', 'target': '13'},
#   {'source': '0', 'target': '14'},
#   {'source': '0', 'target': '15'},
#   {'source': '0', 'target': '16'},
#   {'source': '0', 'target': '17'},
#   {'source': '0', 'target': '18'},
#   {'source': '0', 'target': '19'}],
#  'categories': [{'name': 'T_id'},
#   {'name': 'subject'},
#   {'name': 'method'},
#   {'name': 'compound'},
#   {'name': 'source'}]}

# %%
df_kg = pd.concat([
    pd.read_csv(".data/TA_KG_subject_nodes.csv"),
    pd.read_csv(".data/TA_KG_source_nodes.csv"),
    pd.read_csv(".data/TA_KG_method_nodes.csv"),
    pd.read_csv(".data/TA_KG_compounds_nodes.csv")
], ignore_index=True)
df_info = pd.read_csv(".data/available_TA_all_filtered.csv")

# %%
def paper_info(T_id):
    """
    Get paper information for a given T_id.
    """
    rows = df_backend[df_backend["T_id"] == T_id]
    if rows.empty:
        return {}
    row = rows.iloc[0]
    graph_data = get_graph_data("TA000000",parse_rows(df_all[df_all["T_id"]==T_id]))
    return {
        "T_id": row["T_id"],
        "doi": row["doi"],
        "title": row["title"],
        "authors": row["authors"],
        "year": row["year"],
        "publisher": row["publisher"],
        "abstract": row["abstract"],
        "I_summary": row["I_summary"],
        "M_summary": row["M_summary"],
        "R_summary": row["R_summary"],
        "D_summary": row["D_summary"],
        "C_summary": row["C_summary"],
        "graph_data": graph_data
    }

paper_info("TA000000")
# Out:
# {'T_id': 'TA000000',
#  'doi': '10.3390/foods10061207',
#  'title': 'Yeast Particle Encapsulation of Scaffolded Terpene Compounds for ControlledTerpene Release.',
#  'authors': 'Soto, Ernesto R, Rus, Florentina, Li, Hanchen, Garceau, Carli, Chicca, Jeffrey, Elfawal, Mostafa, Gazzola, David, Nielsen, Martin K, Urban, Joseph F Jr, Aroian, Raffi V, Ostroff, Gary R',
#  'year': np.int64(2021),
#  'publisher': 'Foods (Basel, Switzerland)',
#  'abstract': 'Terpenes are naturally occurring compounds produced by plants that are of greatcommercial interest in the food, agricultural, cosmetic, and pharmaceuticalindustries due to their broad spectra of antibacterial, antifungal, anthelmintic,membrane permeation enhancement, and antioxidant biological activities.Applications of terpenes are often limited by their volatility and the need forsurfactants or alcohols to produce stable, soluble (non-precipitated) products.Yeast particles (YPs) are hollow, porous microspheres that have been used for theencapsulation of terpenes (YP terpenes) by passive diffusion of terpenes throughthe porous YP cell walls. We here report the development of a second generationYP encapsulated terpene technology that incorporates the stimuli-responsivecontrol of terpene release using biodegradable pro-terpene compounds (YPpro-terpenes). YP terpenes and YP pro-terpenes were both produced, in which highlevels of carvacrol, eugenol, thymol and geraniol were encapsulated. The YPpro-terpenes show higher encapsulation stability than YP terpenes due topro-terpenes being non-volatile solids at room temperature and stable insuspensions at neutral pH. YP pro-terpenes and YP terpenes were evaluated forbiological activity in antibacterial, antifungal and anthelmintic assays. The YPpro-terpenes retained the full biological activity of the parent terpenecompound.',
#  'I_summary': 'The introduction provides an overview of terpenes, their sources, functional properties, and challenges in their application, while introducing yeast particles as a solution for encapsulation and controlled release.\n',
#  'M_summary': 'The study involved synthesizing pro-terpenes from parent terpenes and EDTA dianhydride, followed by loading these compounds into yeast particles (YPs) through absorption and swelling methods. The loading efficiency was assessed using Nile red fluorescence microscopy and HPLC quantification. Terpene release kinetics were evaluated in phosphate buffer saline (PBS) at physiological conditions.\nAntimicrobial efficacy of YP-terpenes and YP-pro-terpenes was tested against Escherichia coli and Saccharomyces cerevisiae using microplate assays. Fractionated samples were analyzed to distinguish between supernatant and pellet activity. Simulated digestion assays evaluated terpene stability in gastric and intestinal fluids. Nematode extract assays measured terpene release and antimicrobial activity in parasite-derived environments.\nThe impact of carvacrol and pro-carvacrol on cyathostomin larval development was assessed using an egg-to-larvae assay. Adult hookworm and whipworm motility was measured using the Worminator system to evaluate terpene-induced paralysis or death.\n',
#  'R_summary': 'The study investigated the fumigant toxicity of M. alternifolia essential oil against S. zeamais adults, showing dose- and time-dependent mortality. The LC50 values decreased over time, with terpinen-4-ol and α-terpineol being the most toxic constituents. The oil also significantly inhibited AChE, GST, and CarE enzymes in vivo, with effects varying by dose and duration.\nRNA-Seq analysis revealed significant gene expression changes in S. zeamais after M. alternifolia essential oil fumigation, with 3,562 DEGs identified. Functional annotations linked these DEGs to respiration, xenobiotic metabolism, and detoxification pathways. qRT-PCR validation confirmed the reliability of the RNA-Seq data, highlighting key genes involved in energy metabolism and detoxification.\n',
#  'D_summary': 'Introduction to the importance of terpenes and the challenges in their microencapsulation due to volatility and degradation. Previous development of yeast particle (YP) encapsulation methods for terpenes without alcohols or surfactants, leading to commercialized agricultural products. Goals for the second generation of YP terpenes to improve stability and enable controlled release using pro-terpenes.\nDetails on the encapsulation efficiency and release mechanisms of YP terpenes and pro-terpenes. Improved stability and extended release duration of pro-terpenes compared to terpenes. Biological activity of YP pro-terpenes in antibacterial, antifungal, and anthelmintic assays, mediated by esterase-induced hydrolysis. Potential applications of YP pro-terpenes in environmental biocontrol, oral delivery for gastrointestinal parasites, and controlled-release in food and antimicrobial agents. Future work on in vivo evaluation and expansion of the pro-terpene approach to other small drug molecules.\n',
#  'C_summary': 'The discussion highlights the use of yeast particles (YP) for encapsulating scaffolded terpene compounds with biodegradable linkers to control terpene release. YP pro-terpenes show similar loading capacity to YP terpenes but offer additional advantages such as improved stability and controlled release triggered by pH or esterase-induced hydrolysis. Both YP terpenes and YP pro-terpenes demonstrate biological activity in antimicrobial and anthelmintic assays.\n',
#  'graph_data': {'nodes': [{'id': '0',
#     'name': 'TA000000',
#     'symbolSize': 100,
#     'x': 0,
#     'y': 0,
#     'value': 0,
#     'category': 0},
#    {'id': '1',
#     'name': 'Biotechnology',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Biotechnology',
#     'category': 1},
#    {'id': '2',
#     'name': 'Pharmaceutical Sciences',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Pharmaceutical Sciences',
#     'category': 1},
#    {'id': '3',
#     'name': 'Agricultural Sciences',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Agricultural Sciences',
#     'category': 1},
#    {'id': '4',
#     'name': 'Chemistry',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Chemistry',
#     'category': 1},
#    {'id': '5',
#     'name': 'Microbiology',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Microbiology',
#     'category': 1},
#    {'id': '6',
#     'name': 'Origanum vulgare',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Origanum vulgare',
#     'category': 4},
#    {'id': '7',
#     'name': 'Syzygium aromaticum',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Syzygium aromaticum',
#     'category': 4},
#    {'id': '8',
#     'name': 'Thymus vulgaris',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Thymus vulgaris',
#     'category': 4},
#    {'id': '9',
#     'name': 'Pelargonium graveolens',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'Pelargonium graveolens',
#     'category': 4},
#    {'id': '10',
#     'name': 'database search',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'database search',
#     'category': 2},
#    {'id': '11',
#     'name': 'target prediction',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'target prediction',
#     'category': 2},
#    {'id': '12',
#     'name': 'network construction',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'network construction',
#     'category': 2},
#    {'id': '13',
#     'name': 'enrichment analysis',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'enrichment analysis',
#     'category': 2},
#    {'id': '14',
#     'name': 'molecular docking',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'molecular docking',
#     'category': 2},
#    {'id': '15',
#     'name': 'molecular dynamics simulation',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'molecular dynamics simulation',
#     'category': 2},
#    {'id': '16',
#     'name': 'carvacrol',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'carvacrol',
#     'category': 3},
#    {'id': '17',
#     'name': 'eugenol',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'eugenol',
#     'category': 3},
#    {'id': '18',
#     'name': 'thymol',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'thymol',
#     'category': 3},
#    {'id': '19',
#     'name': 'geraniol',
#     'symbolSize': 40,
#     'x': 0,
#     'y': 0,
#     'value': 'geraniol',
#     'category': 3}],
#   'links': [{'source': '0', 'target': '1'},
#    {'source': '0', 'target': '2'},
#    {'source': '0', 'target': '3'},
#    {'source': '0', 'target': '4'},
#    {'source': '0', 'target': '5'},
#    {'source': '0', 'target': '6'},
#    {'source': '0', 'target': '7'},
#    {'source': '0', 'target': '8'},
#    {'source': '0', 'target': '9'},
#    {'source': '0', 'target': '10'},
#    {'source': '0', 'target': '11'},
#    {'source': '0', 'target': '12'},
#    {'source': '0', 'target': '13'},
#    {'source': '0', 'target': '14'},
#    {'source': '0', 'target': '15'},
#    {'source': '0', 'target': '16'},
#    {'source': '0', 'target': '17'},
#    {'source': '0', 'target': '18'},
#    {'source': '0', 'target': '19'}],
#   'categories': [{'name': 'T_id'},
#    {'name': 'subject'},
#    {'name': 'method'},
#    {'name': 'compound'},
#    {'name': 'source'}]}}
