# %%
import pandas as pd

df = pd.read_csv(".data/chunks_introduction.csv")
df
# Out:
#        introduction_id                                            summary  \
# 0      TA000590_I_0001  Hops (Humulus lupulus L.) are dioecious climbi...
# 1      TA000590_I_0002  Hops belong to the Cannabaceae family and prod...
# 2      TA000590_I_0003  Terpenoid biosynthesis in hops involves the me...
# 3      TA000590_I_0004  New Zealand-grown hop cultivars exhibit unique...
# 4      TA000718_I_0001  The introduction highlights the increasing wil...
# ...                ...                                                ...
# 64464  TA019435_I_0001  The introduction outlines the two pathways for...
# 64465  TA019435_I_0002  The study utilized isotope-labeled intermediat...
# 64466  TA029724_I_0001  The introduction highlights lupeol as a bioact...
# 64467  TA001094_I_0001  The introduction highlights terpenes as versat...
# 64468  TA013149_I_0001  The introduction provides an overview of the g...
#
#                                            original_text
# ...

# %%
rows = df.sample(1)
rows.iloc[0]["summary"]
# Out:
# 'Fucoxanthin, a carotenoid from brown seaweeds, exhibits health benefits but inconsistently affects serum cholesterol in rodents, necessitating detailed study of its impact on cholesterol transport and metabolism.'

# %%
rows
T_id = rows["introduction_id"].values[0][:8]
T_id
# Out:
# 'TA037974'

# %%
df_info = pd.read_csv(".data/available_TA_all_filtered.csv")
# Out:
#            T_id                        doi  \
# 0      TA000000      10.3390/foods10061207
# 1      TA000001  10.3390/molecules23112838
# 2      TA000002  10.3390/molecules27113580
# 3      TA000003  10.3390/molecules23112803
# 4      TA000004  10.1007/s10532-013-9619-4
# ...         ...                        ...
# 45088  TA061686  10.1038/s41419-018-1215-4
# 45089  TA061687  10.1038/s41419-018-1151-3
# 45090  TA061688  10.18632/oncotarget.14160
# 45091  TA061689  10.1186/s12944-018-0793-6
# 45092  TA061690       10.3390/ijms19010076
#
#                                                    title  \
# 0      Yeast Particle Encapsulation of Scaffolded Ter...
# 1      Volatile Terpenes and Terpenoids from Workers ...
# 2      Yeast Particles Hyper-Loaded with Terpenes for...
# 3      Olfactory Impact of Terpene Alcohol on Terpene...
# 4      Using volatile organic compounds to enhance at...
# ...                                                  ...
# ...

# %%
df_info[df_info["T_id"] == T_id]
# Out:
#            T_id                       doi  \
# 21846  TA037974  10.1186/1476-511X-11-112
#
#                                                    title  \
# 21846  Effects of dietary fucoxanthin on cholesterol ...
#
#                                                 abstract  \
# 21846  BACKGROUND: Fucoxanthin is a xanthophyll prese...
#
#                                                  authors  year  \
# 21846  Beppu, Fumiaki, Hosokawa, Masashi, Niwano, Yos...  2012
#
#                           publisher  relevant  \
# 21846  Lipids in health and disease         2
#
#                                                I_summary  \
# 21846  Fucoxanthin, a xanthophyll from brown seaweeds...
#
#                                               I_original  \
# 21846  Fucoxanthin is a xanthophyll present in brown ...
#
#                                                M_summary  \
# 21846  The study involved extracting and purifying fu...
#
# ...
